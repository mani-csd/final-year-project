# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:/marketing_campaign_project/data/processed/cleaned_data.csv")

# %%
sns.countplot(x="Customer_Response", data=df)
plt.show()

# %%
sns.boxplot(x="Customer_Response", y="Revenue_Generated", data=df)
plt.show()
